# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

archivo_csv_1 = r"C:\Users\Alexander\AppData\Roaming\Python\HeadHunters\Head-Hunters\datasets\dataset_glassdoor-jobs-scraper_2023-02-05_01-07-13-866 (1).csv"
archivo_csv_2 = r"C:\Users\Alexander\AppData\Roaming\Python\HeadHunters\Head-Hunters\datasets\ofertas-de-empleo-sample (1).csv"
archivo_csv_3 = r"C:\Users\Alexander\AppData\Roaming\Python\HeadHunters\Head-Hunters\datasets\ofertas-empleo (1).csv"
df1 = pd.read_csv(archivo_csv_1)
df2 = pd.read_csv(archivo_csv_2)
df3 = pd.read_csv(archivo_csv_3)
#print(df1)
#print(df2)
#print(df3)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 36 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   companyDetails/careerOpportunitiesRating      0 non-null      float64
#  1   companyDetails/ceoName                        0 non-null      float64
#  2   companyDetails/ceoName/__typename             25 non-null     object
#  3   companyDetails/ceoName/name                   24 non-null     object
#  4   companyDetails/ceoName/photoUrl               21 non-null     object
#  5   companyDetails/companyRating                  0 non-null      float64
#  6   companyDetails/compensationAndBenefitsRating  0 non-null      float64
#  7   companyDetails/cultureAndValuesRating         0 non-null      float64
#  8   companyDetails/headquarters                   27 non-null     object
# ...

# %%
df1['jobTitle'].values
# Out:
# array(['Client Data Analytics & Models Analyst',
#        'Pricing Data Analytics & Models Analyst', 'Data Analyst',
#        'DATA SCIENTIST ANALYST I', 'Data Analyst Trainee', 'Data Analyst',
#        'Analyst - Business Strategy Consulting', 'Data Analyst',
#        'Operations Data Analyst',
#        'Portfolio & Strategy Analyst (Madrid or Nice)',
#        'Data Analytics Analyst, SAS Programming - European Languages Speaker',
#        'Analyst/Associate, Global Portfolio Advisory',
#        'Analyst, Valuations', 'PRÁCTICAS DATA ANALYST MADRID',
#        'Data Management Analyst BNP PARIBAS',
#        'Data Analyst BNP Paribas Personal Finance', 'HR Data Analyst',
#        'Data Analyst',
#        'Oliver Wyman Digital: Data & Analytics - Analyst/ Senior Analyst/ - Madrid (Spain)',
#        'Financial Reporting Analyst Intern', 'Data Analyst',
#        'Data Analyst',
#        'Internship - Junior Social Media Analyst - Madrid',
# ...

# %%
df1_limpio = df1[['companyDetails/industry/sectorName','companyDetails/name','datePosted','jobLocation','jobTitle']]
df1_limpio.head()
# Out:
#   companyDetails/industry/sectorName companyDetails/name  \
# 0                 Financial Services           Santander
# 1                 Financial Services           Santander
# 2             Information Technology           Logicalis
# 3                 Financial Services                BBVA
# 4                                NaN              Alkemy
#
#                  datePosted         jobLocation  \
# 0  2022-12-02T00:00:00.000Z  Boadilla del Monte
# 1  2023-01-23T00:00:00.000Z  Boadilla del Monte
# 2  2023-02-02T00:00:00.000Z              Madrid
# 3  2022-11-08T00:00:00.000Z              Madrid
# 4  2022-11-24T00:00:00.000Z               Spain
#
#                                   jobTitle
# 0   Client Data Analytics & Models Analyst
# 1  Pricing Data Analytics & Models Analyst
# 2                             Data Analyst
# 3                 DATA SCIENTIST ANALYST I
# 4                     Data Analyst Trainee

# %%
df1_limpio.isnull().sum()
# Out:
# companyDetails/industry/sectorName    5
# companyDetails/name                   0
# datePosted                            0
# jobLocation                           0
# jobTitle                              0
# dtype: int64

# %%
df2.info()
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            400 non-null    object
#  1   description      400 non-null    object
#  2   city             400 non-null    object
#  3   contract_type    400 non-null    object
#  4   workday          400 non-null    object
#  5   company_name     400 non-null    object
#  6   salary_min       159 non-null    float64
#  7   salary_max       146 non-null    float64
#  8   salary_period    159 non-null    object
#  9   salary_currency  159 non-null    object
#  10  teleworking      362 non-null    object
#  11  publish_date     400 non-null    object
# dtypes: float64(2), object(10)
# memory usage: 37.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ...

# %%
df2_limpio = df2[['title','description','company_name','publish_date']]
df3_limpio=df3[['title','description','company_name','publish_date']]
#print(df2_limpio)
#print(df3_limpio)

merged_df = pd.merge(df2_limpio, df3_limpio,on=['title','description','company_name','publish_date'], how='inner')
# Out:
# Empty DataFrame
# Columns: [title, description, company_name, publish_date]
# Index: []
# ...

# %%
df2['salary_type'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Alexander\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\Alexander\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Alexander\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'salary_type'
#
# ...
